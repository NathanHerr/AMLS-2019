# %%
import numpy as np
import pandas as pd
import glob
from natsort import natsorted, ns
import cv2
import dlib
import os
import random
from PIL import Image
from shutil import copyfile
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
import math
from imutils import face_utils
from scipy.spatial import distance
from sklearn.preprocessing import normalize
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors

# %%
# Create list of image names and corresponding gender classifications
image_dic = pd.read_excel('../Datasets/labels_B.xlsx')
image_dic = image_dic[['file_name', 'face_shape']] # Choose columns which are of importance
df = pd.DataFrame(image_dic)
df.to_excel('../Datasets/source_shape_B1/labels_B1.xlsx',index=False)

# %%
# Separate different eye colours and corresponding labels into separate folders

# shape0 = 0
# shape1 = 1
# shape2 = 2
# shape3 = 3
# shape4 = 4

source_eye_color = pd.read_excel('../Datasets/source_shape_B1/labels_B1.xlsx')
source_images_file_paths = glob.glob ("../Datasets/source_images_B1/*.png") #find all paths which match the given path
source_images_file_paths = natsorted(source_images_file_paths) #sort the list of file names such that the image list will be in the correct order

shape0_directory = "../Datasets/sorted_sets_B1/shape0/"
shape1_directory = "../Datasets/sorted_sets_B1/shape1/"
shape2_directory = "../Datasets/sorted_sets_B1/shape2/"
shape3_directory = "../Datasets/sorted_sets_B1/shape3/"
shape4_directory = "../Datasets/sorted_sets_B1/shape4/"

for file_path in source_images_file_paths:
    image = cv2.imread(file_path, cv2.COLOR_RGB2BGR) #read the image
    image_name = os.path.basename(file_path)
    image_label = source_eye_color[source_eye_color['file_name']==image_name]['face_shape'].iloc[0]
    if(image_label == 0):
        directory = ''.join([shape0_directory,os.path.basename(image_name)])
        cv2.imwrite(directory, image)
    elif(image_label == 1):
        directory = ''.join([shape1_directory,os.path.basename(image_name)])
        cv2.imwrite(directory, image)
    elif(image_label == 2):
        directory = ''.join([shape2_directory,os.path.basename(image_name)])
        cv2.imwrite(directory, image)
    elif(image_label == 3):
        directory = ''.join([shape3_directory,os.path.basename(image_name)])
        cv2.imwrite(directory, image)
    elif(image_label == 4):
        directory = ''.join([shape4_directory,os.path.basename(image_name)])
        cv2.imwrite(directory, image)
    else:
        print("no label")

# %%
face_shapes = ["shape0", "shape1", "shape2","shape3","shape4"] #Define shapes

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat") #Or set this to whatever you named the downloaded file

def euclid_distance(p1,p2):
    return distance.euclidean(p1, p2)

def midpoint(p1, p2):
    return [(p1[0]+p2[0])/2, (p1[1]+p2[1])/2]

def get_files(shape): #Define function to get file list, randomly shuffle it and split 80/20
    files = glob.glob("../Datasets/sorted_sets_B1/%s/*.png" %shape)
    return files

def get_landmarks(image):
    detections = detector(image, 1)
    landmarks_vectorised = []
    for k,d in enumerate(detections): #For all detected face instances individually
        shape = predictor(image, d) #Draw Facial Landmarks with the predictor class
        shape = face_utils.shape_to_np(shape)
        forehead = euclid_distance(shape[19], shape[24])
        cheekbones = euclid_distance(shape[36], shape[45])
        jawline = euclid_distance(shape[0], shape[16])
        midpoint_eyebrows = midpoint(shape[19], shape[24])
        face_lenght = euclid_distance(midpoint_eyebrows, shape[8])
        
        #landmarks_vectorised.append(forehead)
        #landmarks_vectorised.append(cheekbones)
        #landmarks_vectorised.append(jawline)
        #landmarks_vectorised.append(face_lenght)
        
        items = list(face_utils.FACIAL_LANDMARKS_IDXS.items())
        name, (i,j) = items[7] #the 7th item in the FACIAL_LANDMARKS_IDXS is the jaw line
        landmarks_vectorised = shape[i:j]                
    if len(detections) < 1:
        return []
    return landmarks_vectorised

def make_sets():
    input_images = []
    labels = []
    for shape in face_shapes:
        print(" working on %s" %shape)
        files = get_files(shape)
        filenumber = 0
        #Append data to training and prediction list, and generate labels 0-1
        for item in files:
            image = cv2.imread(item) #open image
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #convert to grayscale
            landmarks_vectorised = get_landmarks(gray)
            if (landmarks_vectorised != []):
                cv2.imwrite("../Datasets/B1_dataset/%s/%s.jpg" %(shape, filenumber), image) #Write image - don't need to worry about keeping track of labels associated because already sorted
                input_images.append(landmarks_vectorised) #append image array to training data list
                labels.append(face_shapes.index(shape))
                filenumber += 1 #Increment image number                
    training_data, prediction_data, training_labels, prediction_labels = train_test_split(input_images,labels)
    
    return training_data, training_labels, prediction_data, prediction_labels,  input_images, labels

print("Making sets")
training_data, training_labels, prediction_data, prediction_labels, image_inputs, image_labels = make_sets()
# Out:
# Making sets
#  working on shape0
# C:\Users\herrn\Documents\University\Anaconda\lib\site-packages\ipykernel_launcher.py:52: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#  working on shape1
#  working on shape2
#  working on shape3
#  working on shape4

# %%
training_data = np.asarray(training_data)
training_labels = np.asarray(training_labels)
prediction_data = np.asarray(prediction_data)
prediction_labels = np.asarray(prediction_labels)

image_inputs = np.asarray(image_inputs)
image_labels = np.asarray(image_labels)

image_inputs_rs = image_inputs.reshape(image_inputs.shape[0], image_inputs.shape[1]*image_inputs.shape[2])#*image_inputs.shape[3])

print(image_inputs_rs.shape)
print(image_labels.shape)
# Out:
# (8090, 34)
# (8090,)

# %%
# trying PCA -> doesnt seem to work

stndrd_input_images = StandardScaler().fit_transform(image_inputs)

dataframe = pd.DataFrame(stndrd_input_images, columns=['forehead','cheekbones','jawline','face_length'])
dataframe["label"] = image_labels

shape0_df = dataframe[dataframe['label'] == 0]
shape1_df = dataframe[dataframe['label'] == 1]
shape2_df = dataframe[dataframe['label'] == 2]
shape3_df = dataframe[dataframe['label'] == 3]
shape4_df = dataframe[dataframe['label'] == 4]

shape0_inputs = shape0_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape0_labels = shape0_df.filter(['label'], axis=1).values

shape1_inputs = shape1_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape1_labels = shape1_df.filter(['label'], axis=1).values

shape2_inputs = shape2_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape2_labels = shape2_df.filter(['label'], axis=1).values

shape3_inputs = shape3_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape3_labels = shape3_df.filter(['label'], axis=1).values

shape4_inputs = shape4_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape4_labels = shape4_df.filter(['label'], axis=1).values

pca = PCA(n_components=2)

pc_shape0 = pca.fit_transform(shape0_inputs)
pc_shape1 = pca.fit_transform(shape1_inputs)
pc_shape2 = pca.fit_transform(shape2_inputs)
pc_shape3 = pca.fit_transform(shape3_inputs)
pc_shape4 = pca.fit_transform(shape4_inputs)

pc_shape0_df = pd.DataFrame(data = pc_shape0 , columns = ['principal component 1', 'principal component 2'])
pc_shape0_df["label"] = shape0_labels

pc_shape1_df = pd.DataFrame(data = pc_shape1 , columns = ['principal component 1', 'principal component 2'])
pc_shape1_df["label"] = shape1_labels

pc_shape2_df = pd.DataFrame(data = pc_shape2 , columns = ['principal component 1', 'principal component 2'])
pc_shape2_df["label"] = shape2_labels

pc_shape3_df = pd.DataFrame(data = pc_shape3 , columns = ['principal component 1', 'principal component 2'])
pc_shape3_df["label"] = shape3_labels

pc_shape4_df = pd.DataFrame(data = pc_shape4 , columns = ['principal component 1', 'principal component 2'])
pc_shape4_df["label"] = shape4_labels

targets = ["shape0", "shape1", "shape2","shape3","shape4"]
colors = ['red','green','blue', 'yellow', 'black']

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(pc_shape0_df['principal component 1'].values, pc_shape0_df['principal component 2'].values, c = colors[0])
ax.grid()

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(pc_shape1_df['principal component 1'].values, pc_shape1_df['principal component 2'].values, c = colors[1])
ax.grid()

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(pc_shape2_df['principal component 1'].values, pc_shape2_df['principal component 2'].values, c = colors[2])
ax.grid()

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(pc_shape3_df['principal component 1'].values, pc_shape3_df['principal component 2'].values, c = colors[3])
ax.grid()

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(pc_shape4_df['principal component 1'].values, pc_shape4_df['principal component 2'].values, c = colors[4])
ax.grid()

# %%
# IQR for outliers

training_data = np.asarray(training_data)
training_labels = np.asarray(training_labels)
prediction_data = np.asarray(prediction_data)
prediction_labels = np.asarray(prediction_labels)

image_inputs = np.asarray(image_inputs)
image_labels = np.asarray(image_labels)

stndrd_input_images = StandardScaler().fit_transform(image_inputs)

dataframe = pd.DataFrame(stndrd_input_images, columns=['forehead','cheekbones','jawline','face_length'])
dataframe["label"] = image_labels

shape0_df = dataframe[dataframe['label'] == 0]
shape1_df = dataframe[dataframe['label'] == 1]
shape2_df = dataframe[dataframe['label'] == 2]
shape3_df = dataframe[dataframe['label'] == 3]
shape4_df = dataframe[dataframe['label'] == 4]

shape0_inputs = shape0_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape0_labels = shape0_df.filter(['label'], axis=1).values

shape1_inputs = shape1_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape1_labels = shape1_df.filter(['label'], axis=1).values

shape2_inputs = shape2_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape2_labels = shape2_df.filter(['label'], axis=1).values

shape3_inputs = shape3_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape3_labels = shape3_df.filter(['label'], axis=1).values

shape4_inputs = shape4_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1).values
shape4_labels = shape4_df.filter(['label'], axis=1).values

df_shape0_inputs = shape0_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1)
df_shape1_inputs = shape1_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1)
df_shape2_inputs = shape2_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1)
df_shape3_inputs = shape3_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1)
df_shape4_inputs = shape4_df.filter(['forehead','cheekbones','jawline','face_length'], axis=1)

shape0_Q1_fh = np.quantile(df_shape0_inputs['forehead'].values,0.25)
shape0_Q3_fh = np.quantile(df_shape0_inputs['forehead'].values,0.75)
shape0_IQR_fh = shape0_Q3_fh - shape0_Q1_fh
shape0_Minimum_fh = shape0_Q1_fh - 1.5*shape0_IQR_fh
shape0_Maximum_fh = shape0_Q3_fh + 1.5*shape0_IQR_fh

shape0_Q1_cb = np.quantile(df_shape0_inputs['cheekbones'].values,0.25)
shape0_Q3_cb = np.quantile(df_shape0_inputs['cheekbones'].values,0.75)
shape0_IQR_cb = shape0_Q3_cb - shape0_Q1_cb
shape0_Minimum_cb = shape0_Q1_cb - 1.5*shape0_IQR_cb
shape0_Maximum_cb = shape0_Q3_cb + 1.5*shape0_IQR_cb

shape0_Q1_jl = np.quantile(df_shape0_inputs['jawline'].values,0.25)
shape0_Q3_jl = np.quantile(df_shape0_inputs['jawline'].values,0.75)
shape0_IQR_jl = shape0_Q3_jl - shape0_Q1_jl
shape0_Minimum_jl = shape0_Q1_jl - 1.5*shape0_IQR_jl
shape0_Maximum_jl = shape0_Q3_jl + 1.5*shape0_IQR_jl

shape0_Q1_fl = np.quantile(df_shape0_inputs['face_length'].values,0.25)
shape0_Q3_fl = np.quantile(df_shape0_inputs['face_length'].values,0.75)
shape0_IQR_fl = shape0_Q3_fl - shape0_Q1_fl
shape0_Minimum_fl = shape0_Q1_fl - 1.5*shape0_IQR_fl
shape0_Maximum_fl = shape0_Q3_fl + 1.5*shape0_IQR_fl

shape1_Q1_fh = np.quantile(df_shape1_inputs['forehead'].values,0.25)
shape1_Q3_fh = np.quantile(df_shape1_inputs['forehead'].values,0.75)
shape1_IQR_fh = shape1_Q3_fh - shape1_Q1_fh
shape1_Minimum_fh = shape1_Q1_fh - 1.5*shape1_IQR_fh
shape1_Maximum_fh = shape1_Q3_fh + 1.5*shape1_IQR_fh

shape1_Q1_cb = np.quantile(df_shape1_inputs['cheekbones'].values,0.25)
shape1_Q3_cb = np.quantile(df_shape1_inputs['cheekbones'].values,0.75)
shape1_IQR_cb = shape1_Q3_cb - shape1_Q1_cb
shape1_Minimum_cb = shape1_Q1_cb - 1.5*shape1_IQR_cb
shape1_Maximum_cb = shape1_Q3_cb + 1.5*shape1_IQR_cb

shape1_Q1_jl = np.quantile(df_shape1_inputs['jawline'].values,0.25)
shape1_Q3_jl = np.quantile(df_shape1_inputs['jawline'].values,0.75)
shape1_IQR_jl = shape1_Q3_jl - shape1_Q1_jl
shape1_Minimum_jl = shape1_Q1_jl - 1.5*shape1_IQR_jl
shape1_Maximum_jl = shape1_Q3_jl + 1.5*shape1_IQR_jl

shape1_Q1_fl = np.quantile(df_shape1_inputs['face_length'].values,0.25)
shape1_Q3_fl = np.quantile(df_shape1_inputs['face_length'].values,0.75)
shape1_IQR_fl = shape1_Q3_fl - shape1_Q1_fl
shape1_Minimum_fl = shape1_Q1_fl - 1.5*shape1_IQR_fl
shape1_Maximum_fl = shape1_Q3_fl + 1.5*shape1_IQR_fl

shape2_Q1_fh = np.quantile(df_shape2_inputs['forehead'].values,0.25)
shape2_Q3_fh = np.quantile(df_shape2_inputs['forehead'].values,0.75)
shape2_IQR_fh = shape2_Q3_fh - shape2_Q1_fh
shape2_Minimum_fh = shape2_Q1_fh - 1.5*shape2_IQR_fh
shape2_Maximum_fh = shape2_Q3_fh + 1.5*shape2_IQR_fh

shape2_Q1_cb = np.quantile(df_shape2_inputs['cheekbones'].values,0.25)
shape2_Q3_cb = np.quantile(df_shape2_inputs['cheekbones'].values,0.75)
shape2_IQR_cb = shape2_Q3_cb - shape2_Q1_cb
shape2_Minimum_cb = shape2_Q1_cb - 1.5*shape2_IQR_cb
shape2_Maximum_cb = shape2_Q3_cb + 1.5*shape2_IQR_cb

shape2_Q1_jl = np.quantile(df_shape2_inputs['jawline'].values,0.25)
shape2_Q3_jl = np.quantile(df_shape2_inputs['jawline'].values,0.75)
shape2_IQR_jl = shape2_Q3_jl - shape2_Q1_jl
shape2_Minimum_jl = shape2_Q1_jl - 1.5*shape2_IQR_jl
shape2_Maximum_jl = shape2_Q3_jl + 1.5*shape2_IQR_jl

shape2_Q1_fl = np.quantile(df_shape2_inputs['face_length'].values,0.25)
shape2_Q3_fl = np.quantile(df_shape2_inputs['face_length'].values,0.75)
shape2_IQR_fl = shape2_Q3_fl - shape2_Q1_fl
shape2_Minimum_fl = shape2_Q1_fl - 1.5*shape2_IQR_fl
shape2_Maximum_fl = shape2_Q3_fl + 1.5*shape2_IQR_fl

shape3_Q1_fh = np.quantile(df_shape3_inputs['forehead'].values,0.25)
shape3_Q3_fh = np.quantile(df_shape3_inputs['forehead'].values,0.75)
shape3_IQR_fh = shape3_Q3_fh - shape3_Q1_fh
shape3_Minimum_fh = shape3_Q1_fh - 1.5*shape3_IQR_fh
shape3_Maximum_fh = shape3_Q3_fh + 1.5*shape3_IQR_fh

shape3_Q1_cb = np.quantile(df_shape3_inputs['cheekbones'].values,0.25)
shape3_Q3_cb = np.quantile(df_shape3_inputs['cheekbones'].values,0.75)
shape3_IQR_cb = shape3_Q3_cb - shape3_Q1_cb
shape3_Minimum_cb = shape3_Q1_cb - 1.5*shape3_IQR_cb
shape3_Maximum_cb = shape3_Q3_cb + 1.5*shape3_IQR_cb

shape3_Q1_jl = np.quantile(df_shape3_inputs['jawline'].values,0.25)
shape3_Q3_jl = np.quantile(df_shape3_inputs['jawline'].values,0.75)
shape3_IQR_jl = shape3_Q3_jl - shape3_Q1_jl
shape3_Minimum_jl = shape3_Q1_jl - 1.5*shape3_IQR_jl
shape3_Maximum_jl = shape3_Q3_jl + 1.5*shape3_IQR_jl

shape3_Q1_fl = np.quantile(df_shape3_inputs['face_length'].values,0.25)
shape3_Q3_fl = np.quantile(df_shape3_inputs['face_length'].values,0.75)
shape3_IQR_fl = shape3_Q3_fl - shape3_Q1_fl
shape3_Minimum_fl = shape3_Q1_fl - 1.5*shape3_IQR_fl
shape3_Maximum_fl = shape3_Q3_fl + 1.5*shape3_IQR_fl

shape4_Q1_fh = np.quantile(df_shape4_inputs['forehead'].values,0.25)
shape4_Q3_fh = np.quantile(df_shape4_inputs['forehead'].values,0.75)
shape4_IQR_fh = shape4_Q3_fh - shape4_Q1_fh
shape4_Minimum_fh = shape4_Q1_fh - 1.5*shape4_IQR_fh
shape4_Maximum_fh = shape4_Q3_fh + 1.5*shape4_IQR_fh

shape4_Q1_cb = np.quantile(df_shape4_inputs['cheekbones'].values,0.25)
shape4_Q3_cb = np.quantile(df_shape4_inputs['cheekbones'].values,0.75)
shape4_IQR_cb = shape4_Q3_cb - shape4_Q1_cb
shape4_Minimum_cb = shape4_Q1_cb - 1.5*shape4_IQR_cb
shape4_Maximum_cb = shape4_Q3_cb + 1.5*shape4_IQR_cb

shape4_Q1_jl = np.quantile(df_shape4_inputs['jawline'].values,0.25)
shape4_Q3_jl = np.quantile(df_shape4_inputs['jawline'].values,0.75)
shape4_IQR_jl = shape4_Q3_jl - shape4_Q1_jl
shape4_Minimum_jl = shape4_Q1_jl - 1.5*shape4_IQR_jl
shape4_Maximum_jl = shape4_Q3_jl + 1.5*shape4_IQR_jl

shape4_Q1_fl = np.quantile(df_shape4_inputs['face_length'].values,0.25)
shape4_Q3_fl = np.quantile(df_shape4_inputs['face_length'].values,0.75)
shape4_IQR_fl = shape4_Q3_fl - shape4_Q1_fl
shape4_Minimum_fl = shape4_Q1_fl - 1.5*shape4_IQR_fl
shape4_Maximum_fl = shape4_Q3_fl + 1.5*shape4_IQR_fl

idx_keep_shape0 = []
idx_keep_shape1 = []
idx_keep_shape2 = []
idx_keep_shape3 = []
idx_keep_shape4 = []

for i, row in enumerate(shape0_inputs):
    keep = (((row[0] > shape0_Minimum_fh) and (row[0] < shape0_Maximum_fh))
            and ((row[1] > shape0_Minimum_cb) and (row[1] < shape0_Maximum_cb))
            and ((row[2] > shape0_Minimum_jl) and (row[2] < shape0_Maximum_jl))
            and ((row[3] > shape0_Minimum_fl) and (row[3] < shape0_Maximum_fl)))    
    if(keep):
        idx_keep_shape0.append(i)
        
for i, row in enumerate(shape1_inputs):
    keep = (((row[0] > shape1_Minimum_fh) and (row[0] < shape1_Maximum_fh))
            and ((row[1] > shape1_Minimum_cb) and (row[1] < shape1_Maximum_cb))
            and ((row[2] > shape1_Minimum_jl) and (row[2] < shape1_Maximum_jl))
            and ((row[3] > shape1_Minimum_fl) and (row[3] < shape1_Maximum_fl)))    
    if(keep):
        idx_keep_shape1.append(i)
        
for i, row in enumerate(shape2_inputs):
    keep = (((row[0] > shape2_Minimum_fh) and (row[0] < shape2_Maximum_fh))
            and ((row[1] > shape2_Minimum_cb) and (row[1] < shape2_Maximum_cb))
            and ((row[2] > shape2_Minimum_jl) and (row[2] < shape2_Maximum_jl))
            and ((row[3] > shape2_Minimum_fl) and (row[3] < shape2_Maximum_fl)))    
    if(keep):
        idx_keep_shape2.append(i)
        
for i, row in enumerate(shape3_inputs):
    keep = (((row[0] > shape3_Minimum_fh) and (row[0] < shape3_Maximum_fh))
            and ((row[1] > shape3_Minimum_cb) and (row[1] < shape3_Maximum_cb))
            and ((row[2] > shape3_Minimum_jl) and (row[2] < shape3_Maximum_jl))
            and ((row[3] > shape3_Minimum_fl) and (row[3] < shape3_Maximum_fl)))    
    if(keep):
        idx_keep_shape3.append(i)

for i, row in enumerate(shape4_inputs):
    keep = (((row[0] > shape4_Minimum_fh) and (row[0] < shape4_Maximum_fh))
            and ((row[1] > shape4_Minimum_cb) and (row[1] < shape4_Maximum_cb))
            and ((row[2] > shape4_Minimum_jl) and (row[2] < shape4_Maximum_jl))
            and ((row[3] > shape4_Minimum_fl) and (row[3] < shape4_Maximum_fl)))    
    if(keep):
        idx_keep_shape4.append(i)

        
idx_keep_shape0 = np.asarray(idx_keep_shape0)
idx_keep_shape1 = np.asarray(idx_keep_shape1)
idx_keep_shape2 = np.asarray(idx_keep_shape2)
idx_keep_shape3 = np.asarray(idx_keep_shape3)
idx_keep_shape4 = np.asarray(idx_keep_shape4)

new_shape0_inputs_IQR = np.asarray([shape0_inputs[i] for i in idx_keep_shape0])
new_shape0_labels_IQR = np.asarray([shape0_labels[i] for i in idx_keep_shape0])

new_shape1_inputs_IQR = np.asarray([shape1_inputs[i] for i in idx_keep_shape1])
new_shape1_labels_IQR = np.asarray([shape1_labels[i] for i in idx_keep_shape1])

new_shape2_inputs_IQR = np.asarray([shape2_inputs[i] for i in idx_keep_shape2])
new_shape2_labels_IQR = np.asarray([shape2_labels[i] for i in idx_keep_shape2])

new_shape3_inputs_IQR = np.asarray([shape3_inputs[i] for i in idx_keep_shape3])
new_shape3_labels_IQR = np.asarray([shape3_labels[i] for i in idx_keep_shape3])

new_shape4_inputs_IQR = np.asarray([shape4_inputs[i] for i in idx_keep_shape4])
new_shape4_labels_IQR = np.asarray([shape4_labels[i] for i in idx_keep_shape4])

# %%
new_image_inputs = np.concatenate((new_shape0_inputs_IQR, new_shape1_inputs_IQR, new_shape2_inputs_IQR, new_shape3_inputs_IQR, new_shape4_inputs_IQR))
new_image_labels = np.concatenate((new_shape0_labels_IQR, new_shape1_labels_IQR, new_shape2_labels_IQR, new_shape3_labels_IQR, new_shape4_labels_IQR))

print(new_image_inputs.shape)
print(new_image_labels.shape)

new_training_data, new_prediction_data, new_training_labels, new_prediction_labels = train_test_split(new_image_inputs,new_image_labels)

print(new_training_data.shape)
print(new_training_labels.shape)
print(new_prediction_data.shape)
print(new_prediction_labels.shape)

# %%
# Normalise data for clustering

scaler = StandardScaler() 
input_features_scaled = scaler.fit_transform(image_inputs_rs)
df_input_features_scaled = pd.DataFrame(input_features_scaled) 
print(df_input_features_scaled.head())
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.721943  0.590865  0.246466  0.458382 -0.187064  0.393150  0.008464
# 1 -0.183059 -0.871002 -0.345082 -1.011555 -0.780688 -1.167665 -0.992602
# 2 -0.364059 -0.348907 -0.345082 -0.333122 -0.384939 -0.447289 -0.191749
# 3 -0.545059  0.068769 -0.739447  0.119166 -0.978563  0.153024 -0.592176
# 4 -0.545059  0.799703 -0.542265  0.797598 -0.384939  0.753338  0.208677
#
#          7         8         9   ...        24        25        26        27  \
# 0  0.248623  0.117285  0.206435  ... -1.122218  0.456300 -1.131684  0.723245
# 1 -1.195367 -0.938855 -1.181907  ...  0.350857 -0.880864  0.254620 -0.905246
# 2 -0.473372  0.117285 -0.603431  ... -0.753949 -0.100852 -0.265244  0.025320
# 3  0.128290  0.117285 -0.024955  ... -0.385681 -0.212282  0.081332  0.025320
# 4  0.489287  1.173425  0.206435  ... -0.753949  0.122009 -0.091956  0.490603
#
#          28        29        30        31        32        33
# ...

# %%
dataframe = pd.DataFrame(input_features_scaled)
dataframe["label"] = image_labels

shape0_df = dataframe[dataframe['label'] == 0]
shape1_df = dataframe[dataframe['label'] == 1]
shape2_df = dataframe[dataframe['label'] == 2]
shape3_df = dataframe[dataframe['label'] == 3]
shape4_df = dataframe[dataframe['label'] == 4]

shape0_inputs = shape0_df.drop(['label'], axis=1).values
shape0_labels = shape0_df.filter(['label'], axis=1).values

shape1_inputs = shape1_df.drop(['label'], axis=1).values
shape1_labels = shape1_df.filter(['label'], axis=1).values

shape2_inputs = shape2_df.drop(['label'], axis=1).values
shape2_labels = shape2_df.filter(['label'], axis=1).values

shape3_inputs = shape3_df.drop(['label'], axis=1).values
shape3_labels = shape3_df.filter(['label'], axis=1).values

shape4_inputs = shape4_df.drop(['label'], axis=1).values
shape4_labels = shape4_df.filter(['label'], axis=1).values

# %%
neigh = NearestNeighbors(n_neighbors=50)

shape0_nbrs = neigh.fit(shape0_inputs)
shape0_distances, shape0_indices = shape0_nbrs.kneighbors(shape0_inputs)
shape0_distances = shape0_distances[:,1:]
shape0_distances_mean = np.mean(shape0_distances, axis=1)
shape0_distances_mean = np.sort(shape0_distances_mean, axis=0)

shape1_nbrs = neigh.fit(shape1_inputs)
shape1_distances, shape1_indices = shape1_nbrs.kneighbors(shape1_inputs)
shape1_distances = shape1_distances[:,1:]
shape1_distances_mean = np.mean(shape1_distances, axis=1)
shape1_distances_mean = np.sort(shape1_distances_mean, axis=0)

shape2_nbrs = neigh.fit(shape2_inputs)
shape2_distances, shape2_indices = shape2_nbrs.kneighbors(shape2_inputs)
shape2_distances = shape2_distances[:,1:]
shape2_distances_mean = np.mean(shape2_distances, axis=1)
shape2_distances_mean = np.sort(shape2_distances_mean, axis=0)

shape3_nbrs = neigh.fit(shape3_inputs)
shape3_distances, shape3_indices = shape3_nbrs.kneighbors(shape3_inputs)
shape3_distances = shape3_distances[:,1:]
shape3_distances_mean = np.mean(shape3_distances, axis=1)
shape3_distances_mean = np.sort(shape3_distances_mean, axis=0)

shape4_nbrs = neigh.fit(shape4_inputs)
shape4_distances, shape4_indices = shape4_nbrs.kneighbors(shape4_inputs)
shape4_distances = shape4_distances[:,1:]
shape4_distances_mean = np.mean(shape4_distances, axis=1)
shape4_distances_mean = np.sort(shape4_distances_mean, axis=0)

plt.plot(shape0_distances_mean)
plt.show()
plt.plot(shape1_distances_mean)
plt.show()
plt.plot(shape2_distances_mean)
plt.show()
plt.plot(shape3_distances_mean)
plt.show()
plt.plot(shape4_distances_mean)
plt.show()

# %%
# DBSCAN for outlier detection and removal

shape0_dbscan = DBSCAN(eps = 5, min_samples = 1000).fit(shape0_inputs) 
shape0_outlier_labels = shape0_dbscan.labels_

shape1_dbscan = DBSCAN(eps = 5, min_samples = 1000).fit(shape1_inputs) 
shape1_outlier_labels = shape1_dbscan.labels_

shape2_dbscan = DBSCAN(eps = 5, min_samples = 1000).fit(shape2_inputs) 
shape2_outlier_labels = shape2_dbscan.labels_

shape3_dbscan = DBSCAN(eps = 5, min_samples = 1000).fit(shape3_inputs) 
shape3_outlier_labels = shape3_dbscan.labels_

shape4_dbscan = DBSCAN(eps = 5, min_samples = 1000).fit(shape4_inputs) 
shape4_outlier_labels = shape4_dbscan.labels_

print(np.sum(shape0_outlier_labels == -1))
print(np.sum(shape1_outlier_labels == -1))
print(np.sum(shape2_outlier_labels == -1))
print(np.sum(shape3_outlier_labels == -1))
print(np.sum(shape4_outlier_labels == -1))

shape0_non_outlier_idx = np.where(shape0_outlier_labels == 0)[0]
shape1_non_outlier_idx = np.where(shape1_outlier_labels == 0)[0]
shape2_non_outlier_idx = np.where(shape2_outlier_labels == 0)[0]
shape3_non_outlier_idx = np.where(shape3_outlier_labels == 0)[0]
shape4_non_outlier_idx = np.where(shape4_outlier_labels == 0)[0]

new_shape0_inputs_dbscan = np.asarray([shape0_inputs[i] for i in shape0_non_outlier_idx])
new_shape0_labels_dbscan = np.asarray([shape0_labels[i] for i in shape0_non_outlier_idx])

new_shape1_inputs_dbscan = np.asarray([shape1_inputs[i] for i in shape1_non_outlier_idx])
new_shape1_labels_dbscan = np.asarray([shape1_labels[i] for i in shape1_non_outlier_idx])

new_shape2_inputs_dbscan = np.asarray([shape2_inputs[i] for i in shape2_non_outlier_idx])
new_shape2_labels_dbscan = np.asarray([shape2_labels[i] for i in shape2_non_outlier_idx])

new_shape3_inputs_dbscan = np.asarray([shape3_inputs[i] for i in shape3_non_outlier_idx])
new_shape3_labels_dbscan = np.asarray([shape3_labels[i] for i in shape3_non_outlier_idx])

new_shape4_inputs_dbscan = np.asarray([shape4_inputs[i] for i in shape4_non_outlier_idx])
new_shape4_labels_dbscan = np.asarray([shape4_labels[i] for i in shape4_non_outlier_idx])

print(new_shape0_inputs_dbscan.shape)
print(new_shape1_inputs_dbscan.shape)
print(new_shape2_inputs_dbscan.shape)
print(new_shape3_inputs_dbscan.shape)
print(new_shape4_inputs_dbscan.shape)

new_image_inputs = np.concatenate((new_shape0_inputs_dbscan, new_shape1_inputs_dbscan, new_shape2_inputs_dbscan, new_shape3_inputs_dbscan, new_shape4_inputs_dbscan))
new_image_labels = np.concatenate((new_shape0_labels_dbscan, new_shape1_labels_dbscan, new_shape2_labels_dbscan, new_shape3_labels_dbscan, new_shape4_labels_dbscan))

print(new_image_inputs.shape)
print(new_image_labels.shape)

new_training_data, new_prediction_data, new_training_labels, new_prediction_labels = train_test_split(new_image_inputs,new_image_labels)

print("Shape of training and testing data")
print(new_training_data.shape)
print(new_training_labels.shape)
print(new_prediction_data.shape)
print(new_prediction_labels.shape)
# Out:
# 282
# 252
# 193
# 198
# 390
# (1301, 34)
# (1305, 34)
# (1514, 34)
# (1444, 34)
# (1211, 34)
# (6775, 34)
# (6775, 1)
# Shape of training and testing data
# (5081, 34)
# (5081, 1)
# (1694, 34)
# (1694, 1)

# %%
train_data, predict_data, train_labels, predict_labels = train_test_split(image_inputs_rs,image_labels)

print("training SVM") #train SVM
clf = SVC(kernel='rbf')#, verbose = True) #Set the classifier as a support vector machine
clf.fit(new_training_data, new_training_labels)
print("getting accuracy") #Use score() function to get accuracy
pred_lin = clf.score(new_prediction_data, new_prediction_labels)
print ("Accuracy: ", pred_lin)
# Out:
# training SVM
# C:\Users\herrn\Documents\University\Anaconda\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\herrn\Documents\University\Anaconda\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# getting accuracy
# Accuracy:  0.8134592680047226
